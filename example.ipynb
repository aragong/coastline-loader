# %%
import matplotlib.pyplot as plt
from coastline_loader.gshhs import GetCoastline

# %%
# Load to GeoDataFrame from GSHHS database in Esri-shape format
coast = GetCoastline(resolution="f", lonlatbox=(-10, 15, 32.5, 52.5))
coast.gdf
# Out:
#           id  level source  parent_id  sibling_id          area  \
# 0        0-E      1    WVS         -1          -1  5.065405e+07
# 1          1      1    WVS         -1          -1  2.922097e+07
# 2          1      1    WVS         -1          -1  2.922097e+07
# 3         15      1    WVS         -1          -1  2.195175e+05
# 4         26      1    WVS         -1          -1  8.389404e+04
# ...      ...    ...    ...        ...         ...           ...
# 3615  180476      1    WVS         -1          -1  1.356016e-03
# 3616  180479      1    WVS         -1          -1  1.334814e-03
# 3617  180481      1    WVS         -1          -1  1.315525e-03
# 3618  180482      1    WVS         -1          -1  1.305258e-03
# 3619  180484      1    WVS         -1          -1  1.264250e-03
#
#                                                geometry
# 0     POLYGON ((14.99753 44.56956, 14.99617 44.57081...
# 1     POLYGON ((-9.25250 32.50042, -9.25336 32.50042...
# 2     POLYGON ((14.57250 32.50042, 14.57500 32.50042...
# 3     POLYGON ((-0.00500 50.78789, -0.00672 50.78872...
# 4     POLYGON ((-8.00167 51.85789, -8.00333 51.85792...
# ...                                                 ...
# 3615  POLYGON ((12.35169 45.46125, 12.35203 45.46081...
# 3616  POLYGON ((12.76417 41.40622, 12.76447 41.40578...
# 3617  POLYGON ((8.53753 42.36292, 8.53783 42.36247, ...
# 3618  POLYGON ((12.15000 45.38706, 12.15036 45.38667...
# 3619  POLYGON ((12.49833 45.55536, 12.49869 45.55497...
#
# [3620 rows x 7 columns]

# %%
# Plot from GeoDataFrame
coast.gdf.plot()
# Out:
# <AxesSubplot:>

# %%
# Transform to standard DataFrame
df = coast.to_dataframe()
df
# Out:
#         polygon_id  longitude   latitude
# 0                0  14.997528  44.569556
# 1                0  14.996167  44.570806
# 2                0  14.996167  44.572472
# 3                0  14.995861  44.572861
# 4                0  14.994972  44.572861
# ...            ...        ...        ...
# 230244        3618  12.150000  45.387056
# 230245        3619  12.498333  45.555361
# 230246        3619  12.498694  45.554972
# 230247        3619  12.498306  45.554583
# 230248        3619  12.498333  45.555361
#
# [230249 rows x 3 columns]

# %%
# Plot from DataFrame
fig, ax = plt.subplots()
for i in df["polygon_id"].unique():
    df[df["polygon_id"]==i].plot(x="longitude", y="latitude", ax=ax, legend=False)
